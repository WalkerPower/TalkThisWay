# %% [markdown]
# <a href="https://colab.research.google.com/github/WalkerPower/TalkThisWay/blob/main/VibeVoice_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice Colab
# ### 🏷️ **Credits & License**
#
# * 🔗 [VibeVoice GitHub Repository](https://github.com/microsoft/VibeVoice)
# * 🤗 [VibeVoice on Hugging Face](https://huggingface.co/microsoft/VibeVoice-1.5B)
# * 📄 **License**: Provided under the [MIT License](https://github.com/microsoft/VibeVoice/blob/main/LICENSE)
#
# ### ⚠️ **Usage Disclaimer**
#
# This tool enables **AI-generated podcast creation** using cloned voices. While it can be a powerful resource for storytelling, education, and creative projects, it also carries risks if misused. By using this tool, you agree to the following guidelines:
#
# * **No Misrepresentation**: Do not use cloned voices to impersonate real people or mislead listeners into believing AI-generated voices are authentic recordings without disclosure.
# * **Transparency**: Clearly disclose when podcast content has been generated with AI, including synthetic voices or AI-written scripts.
# * **No Harmful Content**: Do not produce or distribute content that promotes hate, harassment, misinformation, defamation, or any form of harmful/deceptive material.
# * **Legal Compliance**: Ensure all use of this tool complies with copyright laws, data protection regulations, and all applicable legal and ethical standards.
# * **Respect for Consent**: Do not replicate or publish anyone’s voice without explicit permission.
#
# > ⚖️ **Legal Responsibility**
#
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
# @title Install VibeVoice

# %cd /content/


# !git clone https://github.com/microsoft/VibeVoice.git
# Download colab.py
# %cd /content/VibeVoice/demo
# !wget https://raw.githubusercontent.com/NeuralFalconYT/VibeVoice/refs/heads/main/demo/colab.py


# (Optional) If you experience compatibility issues with the latest version, you can use a pinned fork instead:
# !git clone https://github.com/NeuralFalconYT/VibeVoice.git



# %cd /content/VibeVoice/
# !pip install -e .
# !pip install pydub>=0.25.1

from IPython.display import clear_output
clear_output()

# %%
#@title Run Official Gradio UI
# !python /content/VibeVoice/demo/gradio_demo.py --model_path "microsoft/VibeVoice-1.5B" --inference_steps 10 --share

# %%
#@title Automatically save podcast to your Google Drive [Optional]
Enable_Drive_Save= True  # @param {type: "boolean"}
if Enable_Drive_Save:
  from google.colab import drive
  drive.mount('/content/gdrive/')

# %%
#@title Run VibeVoice Podcast
# !python /content/VibeVoice/demo/colab.py --model_path microsoft/VibeVoice-1.5B --inference_steps 10 --debug --share
# Out:
# 2026-02-19 18:46:15.933458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771526775.952338    1419 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771526775.958242    1419 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771526775.973762    1419 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526775.973784    1419 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526775.973788    1419 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771526775.973793    1419 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-19 18:46:15.977712: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# 📂 Download directory: /content/VibeVoice/VibeVoice-1.5B
# 📦 Found 9 files in repo 'microsoft/VibeVoice-1.5B'. Checking cache ...
# Processing files:   0% 0/9 [00:00<?, ?file/s]
# .gitattributes:   0% 0.00/1.57k [00:00<?, ?B/s]
# .gitattributes: 16.0kB [00:00, 107kB/s]
# ⬇️ Downloaded: .gitattributes
# Processing files:  11% 1/9 [00:00<00:02,  3.49file/s]
# README.md:   0% 0.00/7.11k [00:00<?, ?B/s]
# README.md: 16.0kB [00:00, 127kB/s]
# ⬇️ Downloaded: README.md
# Processing files:  22% 2/9 [00:00<00:01,  3.69file/s]
# config.json:   0% 0.00/2.70k [00:00<?, ?B/s]
# config.json: 16.0kB [00:00, 130kB/s]
# ⬇️ Downloaded: config.json
# Processing files:  33% 3/9 [00:00<00:01,  3.81file/s]
# Fig1.png:   0% 0.00/150k [00:00<?, ?B/s]
# Fig1.png: 160kB [00:00, 1.13MB/s]
# ⬇️ Downloaded: Fig1.png
# Processing files:  44% 4/9 [00:01<00:01,  3.63file/s]
# model-00001-of-00003.safetensors:   0% 0.00/1.84G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0% 8.00k/1.84G [00:00<10:09:14, 54.0kB/s]
# model-00001-of-00003.safetensors:   1% 22.4M/1.84G [00:00<00:17, 114MB/s]
# model-00001-of-00003.safetensors:   3% 60.4M/1.84G [00:00<00:08, 230MB/s]
# model-00001-of-00003.safetensors:   5% 96.3M/1.84G [00:00<00:06, 284MB/s]
# model-00001-of-00003.safetensors:   7% 125M/1.84G [00:00<00:06, 282MB/s]
# model-00001-of-00003.safetensors:   8% 154M/1.84G [00:00<00:06, 290MB/s]
# model-00001-of-00003.safetensors:  10% 183M/1.84G [00:00<00:06, 283MB/s]
# model-00001-of-00003.safetensors:  11% 214M/1.84G [00:00<00:05, 298MB/s]
# model-00001-of-00003.safetensors:  13% 246M/1.84G [00:00<00:05, 308MB/s]
# model-00001-of-00003.safetensors:  15% 280M/1.84G [00:01<00:05, 321MB/s]
# model-00001-of-00003.safetensors:  16% 311M/1.84G [00:01<00:05, 322MB/s]
# model-00001-of-00003.safetensors:  18% 344M/1.84G [00:01<00:04, 331MB/s]
# model-00001-of-00003.safetensors:  20% 376M/1.84G [00:01<00:04, 329MB/s]
# model-00001-of-00003.safetensors:  22% 408M/1.84G [00:01<00:04, 329MB/s]
# model-00001-of-00003.safetensors:  23% 440M/1.84G [00:01<00:04, 332MB/s]
# model-00001-of-00003.safetensors:  25% 472M/1.84G [00:01<00:04, 320MB/s]
# model-00001-of-00003.safetensors:  27% 502M/1.84G [00:01<00:04, 305MB/s]
# model-00001-of-00003.safetensors:  28% 532M/1.84G [00:01<00:04, 291MB/s]
# model-00001-of-00003.safetensors:  30% 561M/1.84G [00:02<00:04, 296MB/s]
# model-00001-of-00003.safetensors:  31% 589M/1.84G [00:02<00:04, 295MB/s]
# model-00001-of-00003.safetensors:  33% 618M/1.84G [00:02<00:04, 289MB/s]
# model-00001-of-00003.safetensors:  34% 650M/1.84G [00:02<00:04, 303MB/s]
# model-00001-of-00003.safetensors:  36% 679M/1.84G [00:02<00:04, 265MB/s]
# model-00001-of-00003.safetensors:  37% 705M/1.84G [00:02<00:04, 267MB/s]
# model-00001-of-00003.safetensors:  39% 731M/1.84G [00:02<00:04, 266MB/s]
# model-00001-of-00003.safetensors:  40% 757M/1.84G [00:02<00:04, 251MB/s]
# model-00001-of-00003.safetensors:  41% 781M/1.84G [00:04<00:29, 38.6MB/s]
# model-00001-of-00003.safetensors:  42% 799M/1.84G [00:05<00:25, 44.7MB/s]
# model-00001-of-00003.safetensors:  44% 820M/1.84G [00:05<00:19, 57.4MB/s]
# model-00001-of-00003.safetensors:  45% 849M/1.84G [00:05<00:13, 80.9MB/s]
# model-00001-of-00003.safetensors:  47% 881M/1.84G [00:05<00:09, 110MB/s]
# model-00001-of-00003.safetensors:  48% 905M/1.84G [00:05<00:07, 131MB/s]
# model-00001-of-00003.safetensors:  50% 935M/1.84G [00:05<00:06, 161MB/s]
# model-00001-of-00003.safetensors:  51% 964M/1.84G [00:05<00:05, 190MB/s]
# model-00001-of-00003.safetensors:  53% 991M/1.84G [00:05<00:04, 200MB/s]
# model-00001-of-00003.safetensors:  54% 0.99G/1.84G [00:05<00:04, 206MB/s]
# model-00001-of-00003.safetensors:  55% 1.02G/1.84G [00:06<00:04, 216MB/s]
# model-00001-of-00003.safetensors:  57% 1.04G/1.84G [00:06<00:03, 228MB/s]
# model-00001-of-00003.safetensors:  58% 1.06G/1.84G [00:06<00:03, 231MB/s]
# model-00001-of-00003.safetensors:  59% 1.09G/1.84G [00:06<00:03, 245MB/s]
# model-00001-of-00003.safetensors:  61% 1.12G/1.84G [00:06<00:03, 254MB/s]
# model-00001-of-00003.safetensors:  62% 1.14G/1.84G [00:06<00:03, 245MB/s]
# model-00001-of-00003.safetensors:  63% 1.16G/1.84G [00:06<00:02, 247MB/s]
# model-00001-of-00003.safetensors:  65% 1.19G/1.84G [00:06<00:03, 229MB/s]
# model-00001-of-00003.safetensors:  66% 1.21G/1.84G [00:06<00:02, 241MB/s]
# model-00001-of-00003.safetensors:  67% 1.24G/1.84G [00:07<00:02, 244MB/s]
# model-00001-of-00003.safetensors:  69% 1.26G/1.84G [00:07<00:02, 227MB/s]
# model-00001-of-00003.safetensors:  70% 1.29G/1.84G [00:07<00:02, 237MB/s]
# model-00001-of-00003.safetensors:  71% 1.31G/1.84G [00:07<00:02, 254MB/s]
# model-00001-of-00003.safetensors:  73% 1.34G/1.84G [00:07<00:02, 265MB/s]
# model-00001-of-00003.safetensors:  74% 1.37G/1.84G [00:07<00:02, 243MB/s]
# model-00001-of-00003.safetensors:  75% 1.39G/1.84G [00:07<00:01, 247MB/s]
# model-00001-of-00003.safetensors:  77% 1.42G/1.84G [00:07<00:01, 259MB/s]
# model-00001-of-00003.safetensors:  78% 1.44G/1.84G [00:07<00:01, 245MB/s]
# model-00001-of-00003.safetensors:  80% 1.46G/1.84G [00:08<00:01, 235MB/s]
# model-00001-of-00003.safetensors:  81% 1.49G/1.84G [00:08<00:01, 241MB/s]
# model-00001-of-00003.safetensors:  82% 1.51G/1.84G [00:08<00:01, 224MB/s]
# model-00001-of-00003.safetensors:  83% 1.53G/1.84G [00:08<00:01, 220MB/s]
# model-00001-of-00003.safetensors:  84% 1.55G/1.84G [00:08<00:01, 215MB/s]
# model-00001-of-00003.safetensors:  86% 1.58G/1.84G [00:08<00:01, 226MB/s]
# model-00001-of-00003.safetensors:  87% 1.60G/1.84G [00:08<00:01, 236MB/s]
# model-00001-of-00003.safetensors:  88% 1.62G/1.84G [00:08<00:00, 233MB/s]
# model-00001-of-00003.safetensors:  89% 1.65G/1.84G [00:08<00:00, 230MB/s]
# model-00001-of-00003.safetensors:  91% 1.68G/1.84G [00:08<00:00, 258MB/s]
# model-00001-of-00003.safetensors:  93% 1.71G/1.84G [00:09<00:00, 280MB/s]
# model-00001-of-00003.safetensors:  95% 1.74G/1.84G [00:09<00:00, 307MB/s]
# model-00001-of-00003.safetensors:  96% 1.77G/1.84G [00:09<00:00, 317MB/s]
# model-00001-of-00003.safetensors:  98% 1.80G/1.84G [00:09<00:00, 281MB/s]
# model-00001-of-00003.safetensors: 1.84GB [00:09, 206MB/s]
# ⬇️ Downloaded: model-00001-of-00003.safetensors
# Processing files:  56% 5/9 [00:10<00:14,  3.72s/file]
# model-00002-of-00003.safetensors:   0% 0.00/1.85G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0% 8.00k/1.85G [00:00<18:59:21, 29.0kB/s]
# model-00002-of-00003.safetensors:   0% 16.0k/1.85G [00:00<36:11:25, 15.2kB/s]
# model-00002-of-00003.safetensors:   0% 240k/1.85G [00:01<1:42:42, 322kB/s]
# model-00002-of-00003.safetensors:   0% 3.47M/1.85G [00:01<05:44, 5.74MB/s]
# model-00002-of-00003.safetensors:   1% 16.2M/1.85G [00:01<01:06, 29.8MB/s]
# model-00002-of-00003.safetensors:   2% 28.7M/1.85G [00:01<00:38, 50.9MB/s]
# model-00002-of-00003.safetensors:   2% 41.5M/1.85G [00:01<00:27, 70.2MB/s]
# model-00002-of-00003.safetensors:   3% 54.1M/1.85G [00:01<00:22, 85.6MB/s]
# model-00002-of-00003.safetensors:   4% 66.9M/1.85G [00:01<00:19, 98.2MB/s]
# model-00002-of-00003.safetensors:   4% 79.6M/1.85G [00:01<00:17, 108MB/s]
# model-00002-of-00003.safetensors:   5% 91.3M/1.85G [00:01<00:17, 109MB/s]
# model-00002-of-00003.safetensors:   5% 103M/1.85G [00:02<00:16, 112MB/s]
# model-00002-of-00003.safetensors:   6% 115M/1.85G [00:02<00:15, 118MB/s]
# model-00002-of-00003.safetensors:   7% 128M/1.85G [00:02<00:15, 122MB/s]
# model-00002-of-00003.safetensors:   7% 141M/1.85G [00:02<00:14, 125MB/s]
# model-00002-of-00003.safetensors:   8% 153M/1.85G [00:02<00:14, 127MB/s]
# model-00002-of-00003.safetensors:   9% 166M/1.85G [00:02<00:14, 129MB/s]
# model-00002-of-00003.safetensors:   9% 179M/1.85G [00:02<00:15, 118MB/s]
# model-00002-of-00003.safetensors:  10% 191M/1.85G [00:02<00:14, 121MB/s]
# model-00002-of-00003.safetensors:  11% 204M/1.85G [00:02<00:14, 125MB/s]
# model-00002-of-00003.safetensors:  11% 217M/1.85G [00:02<00:13, 127MB/s]
# model-00002-of-00003.safetensors:  12% 229M/1.85G [00:03<00:13, 129MB/s]
# model-00002-of-00003.safetensors:  13% 242M/1.85G [00:03<00:13, 131MB/s]
# model-00002-of-00003.safetensors:  13% 255M/1.85G [00:03<00:13, 131MB/s]
# model-00002-of-00003.safetensors:  14% 268M/1.85G [00:03<00:12, 132MB/s]
# model-00002-of-00003.safetensors:  15% 280M/1.85G [00:03<00:12, 132MB/s]
# model-00002-of-00003.safetensors:  40% 749M/1.85G [00:07<00:09, 132MB/s]
# model-00002-of-00003.safetensors:  40% 762M/1.85G [00:07<00:08, 132MB/s]
# model-00002-of-00003.safetensors:  41% 775M/1.85G [00:08<00:08, 133MB/s]
# model-00002-of-00003.safetensors:  42% 787M/1.85G [00:08<00:08, 133MB/s]
# model-00002-of-00003.safetensors:  42% 800M/1.85G [00:08<00:08, 133MB/s]
# model-00002-of-00003.safetensors:  43% 813M/1.85G [00:08<00:08, 129MB/s]
# model-00002-of-00003.safetensors:  44% 825M/1.85G [00:08<00:08, 128MB/s]
# model-00002-of-00003.safetensors:  44% 838M/1.85G [00:08<00:08, 130MB/s]
# model-00002-of-00003.safetensors:  45% 851M/1.85G [00:08<00:08, 131MB/s]
# model-00002-of-00003.safetensors:  46% 863M/1.85G [00:08<00:08, 132MB/s]
# model-00002-of-00003.safetensors:  46% 876M/1.85G [00:08<00:08, 132MB/s]
# model-00002-of-00003.safetensors:  47% 889M/1.85G [00:08<00:08, 131MB/s]
# model-00002-of-00003.safetensors:  48% 901M/1.85G [00:09<00:07, 131MB/s]
# model-00002-of-00003.safetensors:  48% 914M/1.85G [00:09<00:07, 130MB/s]
# model-00002-of-00003.safetensors:  49% 926M/1.85G [00:09<00:07, 130MB/s]
# model-00002-of-00003.safetensors:  50% 939M/1.85G [00:09<00:07, 130MB/s]
# model-00002-of-00003.safetensors:  50% 951M/1.85G [00:09<00:07, 131MB/s]
# model-00002-of-00003.safetensors:  51% 964M/1.85G [00:09<00:07, 131MB/s]
# model-00002-of-00003.safetensors:  52% 976M/1.85G [00:09<00:07, 121MB/s]
# model-00002-of-00003.safetensors:  52% 989M/1.85G [00:09<00:07, 124MB/s]
# model-00002-of-00003.safetensors:  53% 0.98G/1.85G [00:09<00:07, 125MB/s]
# model-00002-of-00003.safetensors:  54% 0.99G/1.85G [00:09<00:07, 124MB/s]
# model-00002-of-00003.safetensors:  54% 1.00G/1.85G [00:10<00:07, 125MB/s]
# model-00002-of-00003.safetensors:  55% 1.01G/1.85G [00:10<00:07, 127MB/s]
# model-00002-of-00003.safetensors:  56% 1.03G/1.85G [00:10<00:06, 129MB/s]
# model-00002-of-00003.safetensors:  56% 1.04G/1.85G [00:10<00:06, 128MB/s]
# model-00002-of-00003.safetensors:  57% 1.05G/1.85G [00:10<00:06, 129MB/s]
# model-00002-of-00003.safetensors:  58% 1.06G/1.85G [00:10<00:06, 130MB/s]
# model-00002-of-00003.safetensors:  58% 1.07G/1.85G [00:10<00:06, 130MB/s]
# model-00002-of-00003.safetensors:  59% 1.09G/1.85G [00:10<00:06, 130MB/s]
# model-00002-of-00003.safetensors:  60% 1.10G/1.85G [00:10<00:06, 131MB/s]
# model-00002-of-00003.safetensors:  60% 1.11G/1.85G [00:10<00:06, 130MB/s]
# model-00002-of-00003.safetensors:  61% 1.12G/1.85G [00:11<00:05, 131MB/s]
# model-00002-of-00003.safetensors:  62% 1.14G/1.85G [00:11<00:05, 129MB/s]
# model-00002-of-00003.safetensors:  85% 1.57G/1.85G [00:14<00:02, 131MB/s]
# model-00002-of-00003.safetensors:  86% 1.58G/1.85G [00:14<00:02, 131MB/s]
# model-00002-of-00003.safetensors:  86% 1.59G/1.85G [00:14<00:02, 132MB/s]
# model-00002-of-00003.safetensors:  87% 1.61G/1.85G [00:15<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  88% 1.62G/1.85G [00:15<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  88% 1.63G/1.85G [00:15<00:01, 131MB/s]
# model-00002-of-00003.safetensors:  89% 1.64G/1.85G [00:15<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  90% 1.65G/1.85G [00:15<00:01, 132MB/s]
# model-00002-of-00003.safetensors:  90% 1.67G/1.85G [00:15<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  91% 1.68G/1.85G [00:15<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  92% 1.69G/1.85G [00:15<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  92% 1.70G/1.85G [00:15<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  93% 1.72G/1.85G [00:15<00:01, 133MB/s]
# model-00002-of-00003.safetensors:  94% 1.73G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  94% 1.74G/1.85G [00:16<00:00, 131MB/s]
# model-00002-of-00003.safetensors:  95% 1.75G/1.85G [00:16<00:00, 132MB/s]
# model-00002-of-00003.safetensors:  96% 1.77G/1.85G [00:16<00:00, 132MB/s]
# model-00002-of-00003.safetensors:  96% 1.78G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  97% 1.79G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  98% 1.80G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  98% 1.82G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors:  99% 1.83G/1.85G [00:16<00:00, 133MB/s]
# model-00002-of-00003.safetensors: 1.85GB [00:17, 116MB/s]
# ⬇️ Downloaded: model-00002-of-00003.safetensors
# Processing files:  67% 6/9 [00:28<00:24,  8.29s/file]
# model-00003-of-00003.safetensors:   0% 0.00/1.35G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0% 8.00k/1.35G [00:00<6:26:16, 62.6kB/s]
# model-00003-of-00003.safetensors:   0% 608k/1.35G [00:00<07:28, 3.23MB/s]
# model-00003-of-00003.safetensors:   0% 3.12M/1.35G [00:00<01:50, 13.1MB/s]
# model-00003-of-00003.safetensors:   2% 25.2M/1.35G [00:00<00:14, 95.8MB/s]
# model-00003-of-00003.safetensors:   4% 53.5M/1.35G [00:00<00:08, 166MB/s]
# model-00003-of-00003.safetensors:   6% 83.3M/1.35G [00:00<00:06, 215MB/s]
# model-00003-of-00003.safetensors:   8% 111M/1.35G [00:00<00:05, 240MB/s]
# model-00003-of-00003.safetensors:  10% 134M/1.35G [00:00<00:05, 241MB/s]
# model-00003-of-00003.safetensors:  11% 157M/1.35G [00:00<00:05, 241MB/s]
# model-00003-of-00003.safetensors:  13% 180M/1.35G [00:01<00:05, 231MB/s]
# model-00003-of-00003.safetensors:  15% 209M/1.35G [00:01<00:04, 251MB/s]
# model-00003-of-00003.safetensors:  17% 233M/1.35G [00:01<00:04, 252MB/s]
# model-00003-of-00003.safetensors:  19% 258M/1.35G [00:01<00:04, 252MB/s]
# model-00003-of-00003.safetensors:  20% 283M/1.35G [00:01<00:04, 256MB/s]
# model-00003-of-00003.safetensors:  22% 307M/1.35G [00:01<00:04, 256MB/s]
# model-00003-of-00003.safetensors:  24% 332M/1.35G [00:01<00:04, 229MB/s]
# model-00003-of-00003.safetensors:  26% 357M/1.35G [00:01<00:04, 240MB/s]
# model-00003-of-00003.safetensors:  28% 382M/1.35G [00:01<00:04, 245MB/s]
# model-00003-of-00003.safetensors:  29% 406M/1.35G [00:01<00:04, 240MB/s]
# model-00003-of-00003.safetensors:  31% 430M/1.35G [00:02<00:04, 245MB/s]
# model-00003-of-00003.safetensors:  33% 457M/1.35G [00:02<00:03, 256MB/s]
# model-00003-of-00003.safetensors:  35% 485M/1.35G [00:02<00:03, 265MB/s]
# model-00003-of-00003.safetensors:  37% 510M/1.35G [00:02<00:03, 264MB/s]
# model-00003-of-00003.safetensors:  39% 535M/1.35G [00:02<00:06, 128MB/s]
# model-00003-of-00003.safetensors:  40% 555M/1.35G [00:04<00:23, 36.3MB/s]
# model-00003-of-00003.safetensors:  42% 580M/1.35G [00:04<00:16, 49.7MB/s]
# model-00003-of-00003.safetensors:  44% 608M/1.35G [00:04<00:11, 68.6MB/s]
# model-00003-of-00003.safetensors:  46% 636M/1.35G [00:04<00:08, 91.4MB/s]
# model-00003-of-00003.safetensors:  48% 659M/1.35G [00:05<00:07, 104MB/s]
# model-00003-of-00003.safetensors:  49% 681M/1.35G [00:05<00:06, 122MB/s]
# model-00003-of-00003.safetensors:  51% 702M/1.35G [00:05<00:05, 138MB/s]
# model-00003-of-00003.safetensors:  52% 723M/1.35G [00:05<00:04, 153MB/s]
# model-00003-of-00003.safetensors:  54% 744M/1.35G [00:05<00:03, 168MB/s]
# model-00003-of-00003.safetensors:  55% 767M/1.35G [00:05<00:03, 187MB/s]
# model-00003-of-00003.safetensors:  57% 789M/1.35G [00:05<00:03, 195MB/s]
# model-00003-of-00003.safetensors:  59% 814M/1.35G [00:05<00:02, 211MB/s]
# model-00003-of-00003.safetensors:  60% 836M/1.35G [00:05<00:02, 217MB/s]
# model-00003-of-00003.safetensors:  62% 862M/1.35G [00:06<00:02, 232MB/s]
# model-00003-of-00003.safetensors:  64% 891M/1.35G [00:06<00:02, 253MB/s]
# model-00003-of-00003.safetensors:  66% 916M/1.35G [00:06<00:01, 256MB/s]
# model-00003-of-00003.safetensors:  68% 943M/1.35G [00:06<00:01, 265MB/s]
# model-00003-of-00003.safetensors:  70% 969M/1.35G [00:06<00:01, 263MB/s]
# model-00003-of-00003.safetensors:  72% 997M/1.35G [00:06<00:01, 272MB/s]
# model-00003-of-00003.safetensors:  74% 1.01G/1.35G [00:06<00:01, 292MB/s]
# model-00003-of-00003.safetensors:  76% 1.03G/1.35G [00:06<00:01, 293MB/s]
# model-00003-of-00003.safetensors:  79% 1.06G/1.35G [00:06<00:01, 284MB/s]
# model-00003-of-00003.safetensors:  81% 1.09G/1.35G [00:06<00:00, 290MB/s]
# model-00003-of-00003.safetensors:  83% 1.12G/1.35G [00:07<00:00, 295MB/s]
# model-00003-of-00003.safetensors:  85% 1.15G/1.35G [00:07<00:00, 297MB/s]
# model-00003-of-00003.safetensors:  87% 1.17G/1.35G [00:07<00:00, 299MB/s]
# model-00003-of-00003.safetensors:  89% 1.20G/1.35G [00:07<00:00, 299MB/s]
# model-00003-of-00003.safetensors:  91% 1.23G/1.35G [00:07<00:00, 294MB/s]
# model-00003-of-00003.safetensors:  93% 1.26G/1.35G [00:07<00:00, 300MB/s]
# model-00003-of-00003.safetensors:  95% 1.29G/1.35G [00:07<00:00, 302MB/s]
# model-00003-of-00003.safetensors:  97% 1.32G/1.35G [00:07<00:00, 297MB/s]
# model-00003-of-00003.safetensors: 1.35GB [00:07, 184MB/s]
# ⬇️ Downloaded: model-00003-of-00003.safetensors
# Processing files:  78% 7/9 [00:36<00:16,  8.24s/file]
# model.safetensors.index.json:   0% 0.00/120k [00:00<?, ?B/s]
# model.safetensors.index.json: 128kB [00:00, 819kB/s]
# ⬇️ Downloaded: model.safetensors.index.json
# Processing files:  89% 8/9 [00:36<00:05,  5.71s/file]
# preprocessor_config.json:   0% 0.00/351 [00:00<?, ?B/s]
# preprocessor_config.json: 16.0kB [00:00, 124kB/s]
# ⬇️ Downloaded: preprocessor_config.json
# Processing files: 100% 9/9 [00:36<00:00,  4.08s/file]
# 🎙️ Initializing VibeVoice ...
# Loading processor & model from /content/VibeVoice/VibeVoice-1.5B
# tokenizer_config.json: 7.23kB [00:00, 28.6MB/s]
# vocab.json: 2.78MB [00:00, 65.7MB/s]
# merges.txt: 1.67MB [00:00, 146MB/s]
# tokenizer.json: 7.03MB [00:00, 194MB/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# Loading checkpoint shards: 100% 3/3 [00:19<00:00,  6.51s/it]
# Language model attention: sdpa
# Found 9 voice files in /content/VibeVoice/demo/voices
# 🚀 Launching Gradio Demo...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://08ed49dc6ba139228d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Found 10 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_c208ea.wav
# 📄 Timestamps: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_c208ea.json
#
# Found 11 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_b01b4e.wav
# 📄 Timestamps: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_b01b4e.json
#
# Found 12 voice files in /content/VibeVoice/demo/voices
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
# Not running on Google Colab (or Google Drive not mounted). Skipping auto-save.
#
# ✨ Full generation successful!
# 🎵 Audio: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_52c1b8.wav
# 📄 Timestamps: ./podcast_audio/tampon_timmy_stole_a_lot_of_mo_52c1b8.json
